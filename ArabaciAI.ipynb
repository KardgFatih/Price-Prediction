# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
#gerekli kutuphaneleri cagirdik

# %%
#Klasorumuzdeki excel dosyasını dataframe olarak yazdık
mainDataFrame = pd.read_excel("merc.xlsx")
mainDataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
#veride ne var ne yok gormekk icin
mainDataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
#veride bos deger (Null) var mi?
mainDataFrame.isnull().sum()
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
 #ascending=false assagi dogru yukselmesin demek en yuksek en yukarda oluyor yani
mainDataFrame.sort_values("price", ascending=False)
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# ...     ...     ...          ...      ...  ...   ...         ...
# 11549  2002    1495    Automatic    13800  305  39.8         2.7
# 12594  2004    1495       Manual   119000  300  34.5         1.8
# 11765  2000    1490    Automatic    87000  265  27.2         3.2
# 12008  2010    1350       Manual   116126  145  54.3         2.0
# 11816  2003     650       Manual   109090  235  40.0         1.4
#
# [13119 rows x 7 columns]

# %%
plt.figure(figsize=(7,5))
sbn.distplot(mainDataFrame["price"])
# Out:
# C:\Users\karad\AppData\Local\Temp\ipykernel_1488\510534159.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(mainDataFrame["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sbn.violinplot(mainDataFrame["year"])
# Out:
# <Axes: >

# %%
cleanDataFrame = mainDataFrame.sort_values("price", ascending=False).iloc[131:] 
#indekse gore gidicek ve temel python derslerinden hatırlıyondur 131. veriden sonrasini alicalk 131 veri %1 oluyor
#bizim verimiz bu bize en yuksek fiyatlari atilmis yeni bir dataframe veriyor.

# %%
cleanDataFrame
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11816  2003    650       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
sbn.violinplot(cleanDataFrame["year"])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(7,5))
sbn.distplot(cleanDataFrame["price"])
# Out:
# C:\Users\karad\AppData\Local\Temp\ipykernel_1488\1376701116.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(cleanDataFrame["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
cleanDataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
cleanDataFrame
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11816  2003    650       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
cleanDataFrame.drop("transmission", axis = 1)
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 6177   2019  65990     5076  150  30.4         3.0
# 5779   2020  65990      999  145  28.0         4.0
# 3191   2020  65980     3999  145  28.0         4.0
# 4727   2019  65000     3398  145  27.2         4.0
# 8814   2019  64999      119  145  40.9         3.0
# ...     ...    ...      ...  ...   ...         ...
# 11549  2002   1495    13800  305  39.8         2.7
# 12594  2004   1495   119000  300  34.5         1.8
# 11765  2000   1490    87000  265  27.2         3.2
# 12008  2010   1350   116126  145  54.3         2.0
# 11816  2003    650   109090  235  40.0         1.4
#
# [12988 rows x 6 columns]

# %%
cleanDataFrame = cleanDataFrame[cleanDataFrame.year != 1970]

# %%
cleanDataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  12987.000000   12987.000000  12987.000000  12987.000000
# mean    2017.285516  24074.855779   22133.367367    129.676215     55.438392
# std        2.189633   9866.601115   21197.472376     65.167429     15.025902
# min     1997.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17355.000000    6320.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15371.000000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31986.500000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
cleanDataFrame = cleanDataFrame.drop("transmission", axis = 1)
y = cleanDataFrame["price"].values
x = cleanDataFrame.drop("price", axis= 1).values

# %%
cleanDataFrame.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.601965 -0.751131  0.018214 -0.087976   -0.186034
# price       0.601965  1.000000 -0.596331  0.295774 -0.417228    0.425683
# mileage    -0.751131 -0.596331  1.000000 -0.158799  0.191268    0.101772
# tax         0.018214  0.295774 -0.158799  1.000000 -0.517609    0.347113
# mpg        -0.087976 -0.417228  0.191268 -0.517609  1.000000   -0.300254
# engineSize -0.186034  0.425683  0.101772  0.347113 -0.300254    1.000000

# %%
sbn.pairplot(cleanDataFrame)

# %%
x
# Out:
# array([[2.01900e+03, 5.07600e+03, 1.50000e+02, 3.04000e+01, 3.00000e+00],
#        [2.02000e+03, 9.99000e+02, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        [2.02000e+03, 3.99900e+03, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        ...,
#        [2.00000e+03, 8.70000e+04, 2.65000e+02, 2.72000e+01, 3.20000e+00],
#        [2.01000e+03, 1.16126e+05, 1.45000e+02, 5.43000e+01, 2.00000e+00],
#        [2.00300e+03, 1.09090e+05, 2.35000e+02, 4.00000e+01, 1.40000e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.33, random_state=10)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
xTrain = scaler.fit_transform(xTrain)
xTest = scaler.fit_transform(xTest)

len(xTrain) 
#len(yTrain)
# Out:
# 8701

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))
model.compile(optimizer = "adam", loss="mse")

# %%
model.fit(x = xTrain , y=yTrain, validation_data=(xTest,yTest),batch_size=250,epochs = 300)
# Out:
# Epoch 1/300
# 35/35 [==============================] - 1s 6ms/step - loss: 672177536.0000 - val_loss: 686571008.0000
# Epoch 2/300
# 35/35 [==============================] - 0s 2ms/step - loss: 672140224.0000 - val_loss: 686504704.0000
# Epoch 3/300
# 35/35 [==============================] - 0s 2ms/step - loss: 672016128.0000 - val_loss: 686287808.0000
# Epoch 4/300
# 35/35 [==============================] - 0s 2ms/step - loss: 671628672.0000 - val_loss: 685626432.0000
# Epoch 5/300
# 35/35 [==============================] - 0s 3ms/step - loss: 670507648.0000 - val_loss: 683781952.0000
# Epoch 6/300
# 35/35 [==============================] - 0s 3ms/step - loss: 667618304.0000 - val_loss: 679386240.0000
# Epoch 7/300
# 35/35 [==============================] - 0s 2ms/step - loss: 661310144.0000 - val_loss: 670325952.0000
# Epoch 8/300
# 35/35 [==============================] - 0s 3ms/step - loss: 649028032.0000 - val_loss: 653427264.0000
# Epoch 9/300
# ...

# %%
losingData = pd.DataFrame(model.history.history)
losingData.head()
# Out:
#           loss     val_loss
# 0  672177536.0  686571008.0
# 1  672140224.0  686504704.0
# 2  672016128.0  686287808.0
# 3  671628672.0  685626432.0
# 4  670507648.0  683781952.0

# %%
losingData.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
predictionList = model.predict(xTest)
# Out:
# 134/134 [==============================] - 0s 947us/step

# %%
predictionList
# Out:
# array([[21066.445],
#        [22964.139],
#        [24644.316],
#        ...,
#        [ 8676.426],
#        [17261.264],
#        [29849.562]], dtype=float32)

# %%
plt.scatter(yTest, predictionList)
plt.plot(yTest,yTest,"g-*")

# %%
cleanDataFrame.iloc[5]
# Out:
# year           2018.0
# price         64999.0
# mileage       41102.0
# tax             145.0
# mpg              23.0
# engineSize        5.5
# Name: 8083, dtype: float64

# %%
newCar = cleanDataFrame.drop("price",axis=1).iloc[5]

# %%
newCar
# Out:
# year           2018.0
# mileage       41102.0
# tax             145.0
# mpg              23.0
# engineSize        5.5
# Name: 8083, dtype: float64

# %%
newCar = scaler.transform(newCar.values.reshape(-1,5))

# %%
model.predict(newCar)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# array([[51598.473]], dtype=float32)
